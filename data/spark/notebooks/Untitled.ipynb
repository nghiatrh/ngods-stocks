# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

# %%
spark.sql("""
    SELECT date, symbol, open, high, low, close, volume
    FROM parquet.`s3a://warehouse/bronze/market/equity_ohlcv/`
    ORDER BY date DESC, symbol
    LIMIT 20
""").show()
# Out:
# 26/03/30 06:12:34 WARN DataSource: [COLUMN_ALREADY_EXISTS] The column `date` already exists. Consider to choose another name or rename the existing column.
# +----------+------+-----+-----+-----+-----+--------+
# |      date|symbol| open| high|  low|close|  volume|
# +----------+------+-----+-----+-----+-----+--------+
# |2026-03-29|   ACB| 23.4| 23.8| 23.3| 23.8| 7638400|
# |2026-03-29|   ACB| 23.3| 23.5| 23.3| 23.4| 3439200|
# |2026-03-29|   BID| 38.9| 39.9| 38.9|39.85| 8196600|
# |2026-03-29|   BID| 39.1| 39.3|38.95|39.15| 3207200|
# |2026-03-29|   CTG| 33.7| 35.0| 33.6| 34.8|12073500|
# |2026-03-29|   CTG| 34.1| 34.3| 33.9| 34.1| 3274500|
# |2026-03-29|   DGC| 52.7| 52.7| 51.6| 51.8| 5864900|
# |2026-03-29|   DGC| 50.9| 51.0|48.25| 48.8| 5025300|
# |2026-03-29|   FPT| 74.5| 76.3| 74.0| 76.1| 9080300|
# |2026-03-29|   FPT| 74.4| 74.5| 73.5| 73.9| 4801600|
# |2026-03-29|   GAS| 80.4| 82.6| 79.9| 82.1| 2023700|
# |2026-03-29|   GAS| 82.1| 83.2| 80.4| 80.7| 1298700|
# |2026-03-29|   GVR| 30.0| 32.1| 30.0| 32.1| 4463000|
# |2026-03-29|   GVR| 31.2|32.75|31.15|32.25| 2676800|
# |2026-03-29|   HDB| 24.6|25.35|24.55| 25.3|14613100|
# |2026-03-29|   HDB| 24.8|24.85|24.55|24.75| 8904500|
# |2026-03-29|   HPG|25.95| 26.7|25.85| 26.5|26863700|
# |2026-03-29|   HPG|26.15|26.75|25.95| 26.6|18244200|
# |2026-03-29|   LPB| 41.8| 42.2| 41.7| 41.8| 1152800|
# |2026-03-29|   LPB| 41.8| 42.1| 41.2|41.95|  604200|
# +----------+------+-----+-----+-----+-----+--------+
